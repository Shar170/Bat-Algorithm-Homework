# %%
import random
from mpl_toolkits.mplot3d import Axes3D
import math
import numpy as np
from BatAlgorithm import *
import matplotlib.pyplot as plt
from matplotlib import cm

# %% [markdown]
# Функция Изома:
# $${\displaystyle f(x,y)=-\cos \left(x\right)\cos \left(y\right)\exp \left(-\left(\left(x-\pi \right)^{2}+\left(y-\pi \right)^{2}\right)\right)}$$
#                                                     <div align=center> <img src="http://www.geatbx.com/ver_3_3/msh_easo_1_5.gif"> </div>

# %%
def funEasom(d):
    res = 1
    for i in d:
        res = res * math.cos(i) * math.exp(np.sum(-1.0*(np.array(d) - math.pi * np.ones(np.array(d).shape)) ** 2))
    if len(d) % 2 == 0:
        res = -1 * res
    return res

# %% [markdown]
# Функция Шуберта:
# <div align=center> <img src="https://www.sfu.ca/~ssurjano/shubert2.png"> <img src="https://www.sfu.ca/~ssurjano/shubert.png"> </div>

# %%
def funShubert(d):
    res = 1
    for x in d:
        loc_res = 0
        for i in range(1,6):
            loc_res += i*np.cos((i+1)*x+i)
        res = res * loc_res
    return res

# %% [markdown]
# Функция Лангермана:
# <div align=center> <img src="https://www.sfu.ca/~ssurjano/langer2a.png"> </div>
# <div align=center> <img src="https://www.sfu.ca/~ssurjano/langer.png"> </div>

# %%
def funLangerman(d):
    res = 1
    d = np.array(d)
#     res = np.exp((-1/math.pi)* np.sum((d - np.ones(np.array(d).shape)) ** 2))*np.cos(math.pi* np.sum((d - np.ones(np.array(d).shape)) ** 2))
    res = np.exp((-1/math.pi)* np.sum(d * d))*np.cos(math.pi* np.sum(d * d))
    return res

# %% [markdown]
# Функция Розенброка:
# $${\displaystyle f({\boldsymbol {x}})=\sum _{i=1}^{n-1}\left[100\left(x_{i+1}-x_{i}^{2}\right)^{2}+\left(x_{i}-1\right)^{2}\right]}$$
#
# <div align=center> <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Rosenbrock%27s_function_in_3D.pdf/page1-800px-Rosenbrock%27s_function_in_3D.pdf.jpg"> </div>

# %%
def funRosenbroke(d):
    res = 0
    for i in range(0,np.shape(d)[0]-2):
        res += 100*(d[i+1]-d[i]**2)+(d[i]-1)**2
    return res

# %%
dimensi= 4
n_bat=100
n_generasi=100000
r0=0.81
alpha=0.95
gamma=0.95
fmin=0
fmax=1
b_down =-10
b_up =10
maxCount = 600

ba1 = BatAlgorithm(1, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funEasom, maxCount+(1-1)*100)
ba2 = BatAlgorithm(2, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funEasom, maxCount+(2-1)*100)
ba3 = BatAlgorithm(3, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funEasom, maxCount+(3-1)*100)
ba4 = BatAlgorithm(4, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funEasom, maxCount+(4-1)*100)
ba5 = BatAlgorithm(5, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funEasom, maxCount+(5-1)*100)
ba6 = BatAlgorithm(6, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funEasom, maxCount+(6-1)*100)

fig, ax = plt.subplots(figsize=(15,10))
# ax.set_yscale('log')

ba1.proses_ba()
plt.plot(np.array(ba1.history)+1, label='1st dimenshion')

ba2.proses_ba()
plt.plot(np.array(ba2.history)+1, label='2st dimenshion')

ba3.proses_ba()
plt.plot(np.array(ba3.history)+1, label='3st dimenshion')

ba4.proses_ba()
plt.plot(np.array(ba4.history)+1, label='4st dimenshion')

ba5.proses_ba()
plt.plot(np.array(ba5.history)+1, label='5st dimenshion')

ba6.proses_ba()
plt.plot(np.array(ba6.history)+1, label='6st dimenshion')

plt.legend()
# Out:
# Улучшений не было в течении  600  прошло  1202 итераций
# 1202  Решение -1.0000 	 [3.1415971355900307]
# Улучшений не было в течении  700  прошло  1654 итераций
# 1654  Решение -0.9998 	 [3.1395105100271303, 3.1329905575656345]
# Улучшений не было в течении  800  прошло  2015 итераций
# 2015  Решение -0.9960 	 [3.109888661771732, 3.153249997214488, 3.142893387020528]
# Улучшений не было в течении  900  прошло  1802 итераций
# 1802  Решение -0.9716 	 [3.0949715130556577, 3.202127294520871, 3.1470293793815385, 3.1187065094877044]
# Улучшений не было в течении  1000  прошло  2143 итераций
# 2143  Решение -0.8757 	 [3.144703063651284, 3.1146236122073327, 3.0074049981116233, 3.1461622659246324, 3.0683905445007187]
# Улучшений не было в течении  1100  прошло  2449 итераций
# 2449  Решение -0.8063 	 [3.1580973642932424, 3.242097794297041, 3.133477367308363, 3.1202455363077295, 3.1109332022985785, 2.9956975745536867]

# %%
dimensi= 4
n_bat=100
n_generasi=100000
r0=0.81
alpha=0.95
gamma=0.95
fmin=0
fmax=1
b_down =-10
b_up =10
maxCount = 600

ba1 = BatAlgorithm(1, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funShubert, maxCount+(1-1)*100)
ba2 = BatAlgorithm(2, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funShubert, maxCount+(2-1)*100)
ba3 = BatAlgorithm(3, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funShubert, maxCount+(3-1)*100)
ba4 = BatAlgorithm(4, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funShubert, maxCount+(4-1)*100)
ba5 = BatAlgorithm(5, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funShubert, maxCount+(5-1)*100)
ba6 = BatAlgorithm(6, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funShubert, maxCount+(6-1)*100)

fig, ax = plt.subplots(figsize=(15,10))
# ax.set_yscale('log')

ba1.proses_ba()
plt.plot(np.array(ba1.history)+1, label='1st dimenshion')

ba2.proses_ba()
plt.plot(np.array(ba2.history)+1, label='2st dimenshion')

ba3.proses_ba()
plt.plot(np.array(ba3.history)+1, label='3st dimenshion')

ba4.proses_ba()
plt.plot(np.array(ba4.history)+1, label='4st dimenshion')

ba5.proses_ba()
plt.plot(np.array(ba5.history)+1, label='5st dimenshion')

ba6.proses_ba()
plt.plot(np.array(ba6.history)+1, label='6st dimenshion')

plt.legend()
# Out:
# Улучшений не было в течении  600  прошло  1202 итераций
# 1202  Решение -12.8709 	 [-1.42533362587082]
# Улучшений не было в течении  700  прошло  1781 итераций
# 1781  Решение -186.7146 	 [4.859722347727257, 5.480751867959549]
# Улучшений не было в течении  800  прошло  2852 итераций
# 2852  Решение -2702.0440 	 [-7.70021085235728, 5.4707672434909105, -7.085523282529498]
# Улучшений не было в течении  900  прошло  1802 итераций
# 1802  Решение -36697.8945 	 [4.895966896144066, 5.5420184569938025, -0.8273695206300076, -0.7980268396841432]
# Улучшений не было в течении  1000  прошло  2435 итераций
# 2435  Решение -430548.1545 	 [5.344143816355257, -1.4602517726527386, -0.8107774293810022, -0.786514759981095, 5.452185483407258]
# Улучшений не было в течении  1100  прошло  2455 итераций
# 2455  Решение -5983113.2512 	 [-6.989835010477828, 5.382941078382121, 5.4937573014801435, 5.444719770722989, 5.559182491206473, -1.4044181758131364]

# %%
dimensi= 4
n_bat=100
n_generasi=100000
r0=0.81
alpha=0.95
gamma=0.95
fmin=0
fmax=1
b_down =-10
b_up =10
maxCount = 600

ba1 = BatAlgorithm(1, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funLangerman, maxCount+(1-1)*100)
ba2 = BatAlgorithm(2, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funLangerman, maxCount+(2-1)*100)
ba3 = BatAlgorithm(3, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funLangerman, maxCount+(3-1)*100)
ba4 = BatAlgorithm(4, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funLangerman, maxCount+(4-1)*100)
ba5 = BatAlgorithm(5, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funLangerman, maxCount+(5-1)*100)
ba6 = BatAlgorithm(6, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funLangerman, maxCount+(6-1)*100)

fig, ax = plt.subplots(figsize=(15,10))
ax.set_yscale('log')
ax.set_xscale('log')

ba1.proses_ba()
plt.plot(np.array(ba1.history)+1, label='1st dimenshion')

ba2.proses_ba()
plt.plot(np.array(ba2.history)+1, label='2st dimenshion')

ba3.proses_ba()
plt.plot(np.array(ba3.history)+1, label='3st dimenshion')

ba4.proses_ba()
plt.plot(np.array(ba4.history)+1, label='4st dimenshion')

ba5.proses_ba()
plt.plot(np.array(ba5.history)+1, label='5st dimenshion')

ba6.proses_ba()
plt.plot(np.array(ba6.history)+1, label='6st dimenshion')

plt.legend()
# Out:
# Улучшений не было в течении  600  прошло  1202 итераций
# 1202  Решение -0.7311 	 [-0.9838061080013047]
# Улучшений не было в течении  700  прошло  1470 итераций
# 1470  Решение -0.7311 	 [0.9555467929356691, -0.23428473460139343]
# Улучшений не было в течении  800  прошло  2670 итераций
# 2670  Решение -0.7311 	 [0.2431256623169818, -0.9514091953364915, -0.059432152945694816]
# Улучшений не было в течении  900  прошло  1802 итераций
# 1802  Решение -0.7311 	 [0.9426794498380995, -0.13552004890245634, -0.18716396445619957, 0.16093012250007832]
# Улучшений не было в течении  1000  прошло  2002 итераций
# 2002  Решение -0.7311 	 [0.5770177946358033, 0.6935078314391145, 0.11026086746230984, 0.32131141333781027, 0.19617678331302496]
# Улучшений не было в течении  1100  прошло  2202 итераций
# 2202  Решение -0.7311 	 [-0.1257195554826745, 0.19662868388812127, -0.4816824946519992, -0.22166790371792305, -0.7935314374332758, 0.04920232841465966]

# %%
dimensi= 4
n_bat=100
n_generasi=100000
r0=0.81
alpha=0.95
gamma=0.95
fmin=0
fmax=1
b_down =-10
b_up =10
maxCount = 600

ba1 = BatAlgorithm(1, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funRosenbroke, maxCount+(1-1)*100)
ba2 = BatAlgorithm(2, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funRosenbroke, maxCount+(2-1)*100)
ba3 = BatAlgorithm(3, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funRosenbroke, maxCount+(3-1)*100)
ba4 = BatAlgorithm(4, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funRosenbroke, maxCount+(4-1)*100)
ba5 = BatAlgorithm(5, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funRosenbroke, maxCount+(5-1)*100)
ba6 = BatAlgorithm(6, n_bat, n_generasi, r0, alpha, gamma, fmin, fmax, b_down, b_up, funRosenbroke, maxCount+(6-1)*100)

fig, ax = plt.subplots(figsize=(15,10))
# ax.set_yscale('log')

ba1.proses_ba()
plt.plot(np.array(ba1.history)+1, label='1st dimenshion')

ba2.proses_ba()
plt.plot(np.array(ba2.history)+1, label='2st dimenshion')

ba3.proses_ba()
plt.plot(np.array(ba3.history)+1, label='3st dimenshion')

ba4.proses_ba()
plt.plot(np.array(ba4.history)+1, label='4st dimenshion')

ba5.proses_ba()
plt.plot(np.array(ba5.history)+1, label='5st dimenshion')

ba6.proses_ba()
plt.plot(np.array(ba6.history)+1, label='6st dimenshion')

plt.legend()
# Out:
# Улучшений не было в течении  600  прошло  1202 итераций
# 1202  Решение 0.0000 	 [-3.9532961076095674]
# Улучшений не было в течении  700  прошло  1402 итераций
# 1402  Решение 0.0000 	 [2.011837905971765, -7.8577352411215085]
# Улучшений не было в течении  800  прошло  1602 итераций
# 1602  Решение -10919.0000 	 [10, -10, -10]
# Улучшений не было в течении  900  прошло  1802 итераций
# 1802  Решение -21798.0000 	 [10, -10, -10, -8.141294872728837]
# Улучшений не было в течении  1000  прошло  2002 итераций
# 2002  Решение -32637.0000 	 [-10, -10, -10, -10, -10]
# Улучшений не было в течении  1100  прошло  2202 итераций
# 2202  Решение -43516.0000 	 [-10, -10, -10, -10, -10, -0.9338942125465755]
